# %%
# !pip install git+https://github.com/huggingface/parler-tts.git
# Out:
# ...
#   Cloning https://github.com/huggingface/parler-tts.git to /tmp/pip-req-build-iztflk5k
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/parler-tts.git /tmp/pip-req-build-iztflk5k
#   Resolved https://github.com/huggingface/parler-tts.git to commit d108732cd57788ec86bc857d99a6cabd66663d68
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Cloning https://github.com/descriptinc/audiotools to /tmp/pip-install-ofdy7fyn/descript-audiotools_7a7f4b9299a248b5836aa8db301d3025
#   Running command git clone --filter=blob:none --quiet https://github.com/descriptinc/audiotools /tmp/pip-install-ofdy7fyn/descript-audiotools_7a7f4b9299a248b5836aa8db301d3025
#   Resolved https://github.com/descriptinc/audiotools to commit 348ebf2034ce24e2a91a553e3171cb00c0c71678
#   Preparing metadata (setup.py) ... done
# ...

# %%
# !pip install torch-pesq
# Out:
# ...
#   Attempting uninstall: typeguard
#     Found existing installation: typeguard 4.4.1
#     Uninstalling typeguard-4.4.1:
#       Successfully uninstalled typeguard-4.4.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# inflect 7.4.0 requires typeguard>=4.0.1, but you have typeguard 2.13.3 which is incompatible.
# ...

# %%
import torch
from parler_tts import ParlerTTSForConditionalGeneration
from transformers import AutoTokenizer
import soundfile as sf

device = "cuda:0" if torch.cuda.is_available() else "cpu"

model = ParlerTTSForConditionalGeneration.from_pretrained("parler-tts/parler-tts-mini-jenny-30H").to(device)
tokenizer = AutoTokenizer.from_pretrained("parler-tts/parler-tts-mini-jenny-30H")
# Out:
# WARNING:parler_tts.modeling_parler_tts:Flash attention 2 is not installed
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/utils/weight_norm.py:143: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# ...

# %%
import pandas as pd

df = pd.read_parquet('data.parquet')

# %%
df
# Out:
#         file_name                                      transcription  \
# 0      jenny/1201  They were all impregnable, as the Party intend...
# 1     jenny/12020  For example, most invertebrate animals in the ...
# 2     jenny/12021  In contrast, ocean bony fishes have body fluid...
# 3     jenny/12022  Finally, freshwater animals have body fluids t...
# 4     jenny/12023  Typical ions that can be found in an animal's ...
# ...           ...                                                ...
# 2093  jenny/14000  Even in the individual atom, the substance is ...
# 2094  jenny/14001               So this miniscule is our engagement.
# 2095  jenny/14002  How I see, in my experience, is it's only the ...
# 2096  jenny/14003              We are so engaged with the footprint.
# 2097  jenny/14004       At one time, I was involved in tiger census.
#
#                                transcription_normalised  \
# 0     they were all impregnable, as the party intend...
# ...

# %%
description = "Jenny speaks at an average pace with an animated delivery in a very confined sounding environment with clear audio quality."

# %%
import io
import soundfile as sf
from torch_pesq import PesqLoss
import librosa

model_sr = 44100

pesq = PesqLoss(0.5,
    sample_rate=model_sr,
)
from tqdm import trange

sum_pesq = 0
for i in trange(100):
  audio_bytes = df["audio"][i]["bytes"]
  prompt = df["transcription"][i]
  reference, sr1 = sf.read(io.BytesIO(audio_bytes))
  reference = librosa.resample(reference, orig_sr=sr1, target_sr=model_sr)
  reference = reference / np.max(np.abs(reference))

  input_ids = tokenizer(description, return_tensors="pt").input_ids.to(device)
  prompt_input_ids = tokenizer(prompt, return_tensors="pt").input_ids.to(device)

  generation = model.generate(input_ids=input_ids, prompt_input_ids=prompt_input_ids)
  audio_arr = generation.cpu().numpy().squeeze()
  sf.write("parler_tts_out.wav", audio_arr, model.config.sampling_rate)
  synthesized, sr2 = sf.read("parler_tts_out.wav")
  synthesized = synthesized / np.max(np.abs(synthesized))


  max_len = max(len(reference), len(synthesized))
  reference = np.pad(reference, (0, max_len - len(reference)))
  synthesized = np.pad(synthesized, (0, max_len - len(synthesized)))


  # Оценка PESQ
  pesq_score = pesq(torch.tensor(reference, dtype=torch.float32), torch.tensor(synthesized, dtype=torch.float32)).item()
  sum_pesq += pesq_score
print()
print(f"PESQ: {mean_pesq / 100}")
# Out:
# 100%|██████████| 100/100 [20:52<00:00, 12.52s/it]
# PESQ: 0.026288754205949543
